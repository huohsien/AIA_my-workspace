# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# data = pd.read_csv('./house-prices-advanced-regression-techniques/train.csv')
# ax = data.plot.scatter(x='LotArea', y='SalePrice',xlim=(0,50000))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm as cm

data = pd.read_csv('./house-prices-advanced-regression-techniques/train.csv', keep_default_na=True)
data = data.drop("Id", axis=1)
SalePrice_col = data.loc[:,'SalePrice']
data = data.drop("SalePrice", axis=1)
data.insert(loc=0, column='SalePrice', value=SalePrice_col)

correlations = data.corr()

names = correlations.columns.tolist()
fig = plt.figure(figsize=(32,15))
ax = fig.add_subplot(111)
ax.grid(True)
cmap = cm.get_cmap('jet', 30)
cax = ax.matshow(correlations, vmin = -1, vmax = 1, cmap = cmap)
fig.colorbar(cax)
ticks = np.arange(0,len(names), 1)
ax.set_xticklabels([" "] * len(names))
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_yticklabels(names)
plt.show()
numeric_features1 = set(correlations.columns.tolist())
print(numeric_features1)
print("num=", len(correlations.columns.tolist()))
# Out:
# {'OpenPorchSF', 'SalePrice', 'YearRemodAdd', 'Fireplaces', 'KitchenAbvGr', 'LotFrontage', 'TotRmsAbvGrd', 'OverallQual', 'MasVnrArea', '2ndFlrSF', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', '3SsnPorch', 'HalfBath', 'GrLivArea', 'EnclosedPorch', 'MSSubClass', 'FullBath', 'ScreenPorch', 'PoolArea', 'MiscVal', 'LotArea', 'LowQualFinSF', 'BsmtHalfBath', 'BedroomAbvGr', 'OverallCond', 'BsmtFinSF1', 'TotalBsmtSF', 'BsmtFinSF2', '1stFlrSF', 'YrSold', 'YearBuilt', 'MoSold', 'BsmtFullBath', 'BsmtUnfSF'}
# num= 37

# %% [markdown]
# ## Check type of each feature

# %%
num = 0
numeric_features2 = set()

for key in data.keys():
    if str(type(data[key][0])) != '<class \'str\'>':
        #print(key," , ", type(data[key][0]))
        numeric_features2.add(key)
        num += 1
            
print("num=",num)
# Out:
# num= 42

# %% [markdown]
# ## Show difference in feature sets

# %%
d1 = numeric_features2.difference(numeric_features1)
d1
# Out:
# {'Alley', 'Fence', 'FireplaceQu', 'MiscFeature', 'PoolQC'}

# %%
data.loc[:2,'MSSubClass']
# Out:
# 0    60
# 1    20
# 2    60
# Name: MSSubClass, dtype: int64

# %%
data2 = pd.read_csv('./house-prices-advanced-regression-techniques/train.csv', keep_default_na=False)
data2 = data2.drop("Id", axis=1)
SalePrice_col2 = data2.loc[:,'SalePrice']
data2 = data2.drop("SalePrice", axis=1)
data2.insert(loc=0, column='SalePrice', value=SalePrice_col2)

correlations2 = data2.corr()
numeric_features3 = set(correlations2.columns.tolist())
print(numeric_features3)
print("num=", len(numeric_features3))
# Out:
# {'OpenPorchSF', 'SalePrice', 'YearRemodAdd', 'Fireplaces', 'KitchenAbvGr', 'TotRmsAbvGrd', 'OverallQual', '2ndFlrSF', 'GarageArea', '3SsnPorch', 'GarageCars', 'WoodDeckSF', 'HalfBath', 'GrLivArea', 'EnclosedPorch', 'MSSubClass', 'FullBath', 'ScreenPorch', 'PoolArea', 'MiscVal', 'LotArea', 'LowQualFinSF', 'BedroomAbvGr', 'BsmtHalfBath', 'OverallCond', 'BsmtFinSF1', 'TotalBsmtSF', 'BsmtFinSF2', '1stFlrSF', 'YrSold', 'YearBuilt', 'MoSold', 'BsmtFullBath', 'BsmtUnfSF'}
# num= 34

# %%
d2 = numeric_features2.difference(numeric_features3)
d2
# Out:
# {'Alley',
#  'Fence',
#  'FireplaceQu',
#  'GarageYrBlt',
#  'LotFrontage',
#  'MasVnrArea',
#  'MiscFeature',
#  'PoolQC'}

# %% [markdown]
# ## Columns with missing values marked as NA

# %%
d2.difference(d1)
# Out:
# {'GarageYrBlt', 'LotFrontage', 'MasVnrArea'}

# %% [markdown]
# # START

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm as cm
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

data = pd.read_csv('./house-prices-advanced-regression-techniques/train.csv', keep_default_na=False)
data = data.drop("Id", axis=1)
sale_price_col = data.loc[:,'SalePrice']
data = data.drop("SalePrice", axis=1)

correlations = data.corr()
features = correlations.columns.tolist()

X = data[features].values
y = np.log(sale_price_col.values)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 7, test_size = 0.33)

# %%
eval_set =  [(X_test, y_test)]
eval_set
# Out:
# [(array([[   20, 12464,     5, ...,     0,    11,  2009],
#          [   60, 11218,     6, ...,   400,     5,  2010],
#          [   60, 15578,     6, ...,     0,     5,  2006],
#          ...,
#          [  120,  4224,     5, ...,     0,     6,  2007],
#          [   20,  7931,     5, ...,     0,     7,  2009],
#          [   30, 10800,     5, ...,     0,     6,  2006]]),
#   array([11.9316358 , 12.14950229, 12.05980333, 11.00209984, 11.71993963,
#          12.66980666, 11.86709728, 11.72803684, 11.8277362 , 11.77143616,
#          12.41543365, 12.08672589, 11.60367983, 11.95655303, 12.15477935,
#          12.08953883, 12.15477935, 11.9316358 , 11.8493977 , 12.04355372,
#          12.11724143, 11.90496755, 11.75978554, 12.46843691, 12.65395847,
#          11.57119437, 11.56171563, 12.10071213, 12.26857785, 11.65268741,
#          12.00089179, 12.18586994, 12.66539443, 12.44901882, 12.06104687,
#          12.38421883, 11.81228904, 11.89818787, 12.50617724, 12.20607265,
#          11.56646623, 12.06104687, 11.9511804 , 11.98292909, 12.68849879,
#          12.27839331, 12.21849517, 12.02574909, 12.39669301, 12.27373129,
#          12.52452638, 12.01974307, 11.96356787, 12.16785143, 11.6784399 ,
#          11.72803684, 12.53177279, 11.89478071, 12.23999086, 12.16525065,
#          11.88103479, 12.33929149, 11.8493977 , 11.7829526 , 11.40756495,
#          12.10699237, 11.75978554, 12.05757264, 11.89818787, 11.99535161,
#          12.30591798, 11.94470788, 11.48246626, 11.73606902, 13.07107008,
#          12.67607627, 12.01370075, 11.58988651, 11.8493977 , 11.49272276,
#          11.88448902, 12.95512746, 12.1281111 , 12.88520203, 12.7512997 ,
#          11.77721096, 11.68687877, 11.81303006, 12.86099861, 11.44571672,
#          12.8139179 , 11.72803684, 13.09190417, 12.04941884, 11.66564655,
#          12.1281111 , 12.31043266, 11.75587164, 11.8493977 , 11.76756768,
#          11.87687389, 11.84078933, 12.54075757, 12.17498953, 11.76756768,
#          12.32163099, 11.79810441, 12.53357621, 12.23076526, 11.8277362 ,
#          11.32659589, 11.38509209, 12.34583459, 12.22046853, 12.4292162 ,
#          11.83101549, 11.84222921, 11.3736634 , 12.37370349, 12.22096126,
#          11.62625415, 12.33138284, 12.56723749, 11.73606902, 12.34800614,
#          12.66999847, 12.06104687, 12.99175343, 12.01370075, 11.72803684,
#          11.94470788, 11.82700601, 11.7905572 , 11.59910316, 12.33710091,
#          11.6127708 , 12.56024446, 11.35040654, 11.28853113, 11.94194433,
#          11.88448902, 12.14950229, 12.13618652, 12.86099861, 12.22587527,
#          11.75978554, 12.26434155, 13.19561384, 11.98292909, 11.9511804 ,
#          11.9316358 , 11.34450681, 11.43927892, 11.75978554, 11.74799759,
#          12.07823927, 11.65268741, 11.88448902, 12.7367009 , 11.87059991,
#          11.8493977 , 12.49125159, 11.79244935, 12.34346657, 13.5211395 ,
#          11.86709728, 12.24673463, 12.27373129, 12.04349489, 12.3327053 ,
#          11.75978554, 11.6351431 , 11.58988651, 11.33260191, 12.36734079,
#          12.17818744, 11.77528973, 11.94405832, 11.04104808, 12.10071213,
#          11.69940503, 12.16525065, 11.45899712, 12.23027733, 12.04355372,
#          11.75587164, 12.15477935, 12.35449265, 11.81672692, 12.18586994,
#          11.69524702, 11.87756858, 11.6351431 , 12.14153412, 12.19095901,
#          12.46997419, 11.71993963, 12.09514108, 12.85055465, 12.37158708,
#          12.53537639, 12.10071213, 12.03112384, 12.4423022 , 11.58524613,
#          11.8968264 , 12.10625231, 12.17664898, 12.14791373, 12.8411298 ,
#          11.45635511, 12.14153412, 12.02873863, 12.2353887 , 12.79917571,
#          12.38421883, 11.9697172 , 12.08953883, 11.34450681, 12.10348606,
#          12.60148742, 11.71586631, 12.03171926, 12.12757042, 12.00150548,
#          11.83428406, 11.91772368, 11.28978191, 12.26904744, 11.80559508,
#          11.8493977 , 11.42954386, 11.92171836, 11.87059991, 12.56755103,
#          12.29778545, 12.56723749, 12.50432367, 12.4874851 , 11.51192496,
#          11.65268741, 11.99843328, 12.63101353, 12.29910751, 12.52088339,
#          12.5098741 , 11.76756768, 12.25486281, 12.39255221, 11.9797992 ,
#          12.25961341, 11.1124479 , 11.60823564, 11.35627165, 12.86424011,
#          11.38509209, 11.29601246, 12.08672589, 12.01370075, 12.07823927,
#          12.07254125, 12.03171926, 11.96400108, 12.08099117, 11.7352687 ,
#          12.45293272, 11.91772368, 11.81154748, 11.88448902, 11.77528973,
#          12.93675161, 12.10348606, 12.47800636, 11.8493977 , 11.7745202 ,
#          11.79433792, 11.69524702]))]

# %%
model = xgb.XGBRegressor()
model.fit(X_train, y_train, early_stopping_rounds=10,
          eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-rmse:10.3949
# Will train until validation_0-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:9.36011
# [2]	validation_0-rmse:8.42891
# [3]	validation_0-rmse:7.59094
# [4]	validation_0-rmse:6.8353
# [5]	validation_0-rmse:6.1552
# [6]	validation_0-rmse:5.5454
# [7]	validation_0-rmse:4.99491
# [8]	validation_0-rmse:4.49896
# [9]	validation_0-rmse:4.05448
# [10]	validation_0-rmse:3.65316
# [11]	validation_0-rmse:3.2901
# [12]	validation_0-rmse:2.96456
# [13]	validation_0-rmse:2.67104
# [14]	validation_0-rmse:2.40823
# [15]	validation_0-rmse:2.16976
# [16]	validation_0-rmse:1.95633
# [17]	validation_0-rmse:1.76464
# [18]	validation_0-rmse:1.59055
# [19]	validation_0-rmse:1.43416
# [20]	validation_0-rmse:1.29465
# [21]	validation_0-rmse:1.16938
# [22]	validation_0-rmse:1.05681
# [23]	validation_0-rmse:0.95546
# [24]	validation_0-rmse:0.86478
# [25]	validation_0-rmse:0.782841
# [26]	validation_0-rmse:0.709634
# [27]	validation_0-rmse:0.643391
# [28]	validation_0-rmse:0.584239
# [29]	validation_0-rmse:0.530764
# [30]	validation_0-rmse:0.483447
# [31]	validation_0-rmse:0.441066
# [32]	validation_0-rmse:0.403593
# [33]	validation_0-rmse:0.369771
# [34]	validation_0-rmse:0.340001
# [35]	validation_0-rmse:0.313592
# [36]	validation_0-rmse:0.290351
# [37]	validation_0-rmse:0.270141
# [38]	validation_0-rmse:0.252048
# [39]	validation_0-rmse:0.236782
# [40]	validation_0-rmse:0.22302
# [41]	validation_0-rmse:0.211244
# [42]	validation_0-rmse:0.201254
# [43]	validation_0-rmse:0.192307
# [44]	validation_0-rmse:0.184653
# [45]	validation_0-rmse:0.177978
# [46]	validation_0-rmse:0.172468
# [47]	validation_0-rmse:0.167718
# [48]	validation_0-rmse:0.163691
# [49]	validation_0-rmse:0.160172
# [50]	validation_0-rmse:0.157274
# [51]	validation_0-rmse:0.154741
# [52]	validation_0-rmse:0.153037
# [53]	validation_0-rmse:0.151102
# [54]	validation_0-rmse:0.14966
# [55]	validation_0-rmse:0.14825
# [56]	validation_0-rmse:0.147117
# [57]	validation_0-rmse:0.14602
# [58]	validation_0-rmse:0.14488
# [59]	validation_0-rmse:0.144145
# [60]	validation_0-rmse:0.143379
# [61]	validation_0-rmse:0.142742
# [62]	validation_0-rmse:0.142456
# [63]	validation_0-rmse:0.141996
# [64]	validation_0-rmse:0.141699
# [65]	validation_0-rmse:0.141278
# [66]	validation_0-rmse:0.141036
# [67]	validation_0-rmse:0.140762
# [68]	validation_0-rmse:0.140332
# [69]	validation_0-rmse:0.140165
# [70]	validation_0-rmse:0.139884
# [71]	validation_0-rmse:0.139609
# [72]	validation_0-rmse:0.139416
# [73]	validation_0-rmse:0.139267
# [74]	validation_0-rmse:0.139104
# [75]	validation_0-rmse:0.138742
# [76]	validation_0-rmse:0.138251
# [77]	validation_0-rmse:0.13806
# [78]	validation_0-rmse:0.137802
# [79]	validation_0-rmse:0.137702
# [80]	validation_0-rmse:0.137479
# [81]	validation_0-rmse:0.137363
# [82]	validation_0-rmse:0.13723
# [83]	validation_0-rmse:0.137052
# [84]	validation_0-rmse:0.136997
# [85]	validation_0-rmse:0.136648
# [86]	validation_0-rmse:0.136489
# [87]	validation_0-rmse:0.136577
# [88]	validation_0-rmse:0.136508
# [89]	validation_0-rmse:0.136346
# [90]	validation_0-rmse:0.136125
# [91]	validation_0-rmse:0.136065
# [92]	validation_0-rmse:0.135828
# [93]	validation_0-rmse:0.135651
# [94]	validation_0-rmse:0.135559
# [95]	validation_0-rmse:0.135436
# [96]	validation_0-rmse:0.135236
# [97]	validation_0-rmse:0.135205
# [98]	validation_0-rmse:0.135123
# [99]	validation_0-rmse:0.134995
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# we use model.predict to get the label
y_pred = model.predict(X_test)
# Out:
# array([11.928804, 12.110842, 12.046588, 11.629565, 11.761052],
#       dtype=float32)
